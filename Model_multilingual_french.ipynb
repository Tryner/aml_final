# %%
#Colab
'''
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/MyDrive/aml_final
# %cd /content/drive/MyDrive/CDA/Erasmus/AML/aml_final-main
#with open("github_token.txt", "r") as f:
#  token = f.read()
#! git clone https://{token}@github.com/Tryner/aml_final.git #clone repo
# %cd aml_final/
! git pull
! pip install setfit
! pip install -U sentence-transformers

'''

# %%
from collections import Counter

import torch
from data.load_datasets import load_french_dataset
from datasets import load_dataset, Dataset
from setfit import SetFitModel, Trainer, TrainingArguments
from train.active_learning import ActiveTrainer
from train.active_learning_config import ActiveLearningConfig
from data.dataset_config import DatasetConfig
from sentence_transformers import SentenceTransformer

# %%
dataset = load_french_dataset("french_twitter_reduced")
active_learning_config = ActiveLearningConfig()
dataset_config = DatasetConfig()
train_args = TrainingArguments()

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
def model_init():
    return SetFitModel.from_pretrained("sentence-transformers/paraphrase-multilingual-mpnet-base-v2", use_differentiable_head=True, head_params={"out_features": dataset_config.num_classes}).to(device)
def after_train_callback(trainer: Trainer):
    print("#Accuraccy: " + str(trainer.evaluate()))
def dataset_callback(dataset: Dataset):
    print("#Labels: " + str(Counter(dataset[dataset_config.label_column])))
# Out:
# cuda

# %%
trainer = ActiveTrainer(
    model_init=model_init,
    full_train_dataset=dataset["train"],
    eval_dataset=dataset["validation"],
    train_args=train_args,
    active_learning_config=active_learning_config,
    dataset_config=dataset_config,
    after_train_callback=after_train_callback,
    dataset_callback=dataset_callback,
    )
# Out:
# Casting the dataset:   0%|          | 0/8 [00:00<?, ? examples/s]

# %%
trainer.train()
# Out:
# Applying column mapping to the training dataset
# Applying column mapping to the evaluation dataset
# config.json:   0%|          | 0.00/723 [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/690 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.10k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/723 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/402 [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# model_head.pkl not found on HuggingFace Hub, initialising classification head with random weights. You should TRAIN this model on a downstream task to use it for predictions and inference.
# Map:   0%|          | 0/8 [00:00<?, ? examples/s]
# ***** Running training *****
#   Num examples = 3
#   Num epochs = 1
#   Total optimization steps = 3
#   Total train batch size = 16
#     <div>
#
#       <progress value='3' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3/3 00:00, Epoch 1/0]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# The `max_length` is `None`. Using the maximum acceptable length according to the current model body: 128.
# Epoch:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# ***** Running evaluation *****
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]
# #Accuraccy: {'accuracy': 0.693}
# Applying column mapping to the training dataset
# Applying column mapping to the evaluation dataset
# #Labels: Counter({0: 11, 1: 5})
# model_head.pkl not found on HuggingFace Hub, initialising classification head with random weights. You should TRAIN this model on a downstream task to use it for predictions and inference.
# Map:   0%|          | 0/16 [00:00<?, ? examples/s]
# ***** Running training *****
#   Num examples = 11
#   Num epochs = 1
#   Total optimization steps = 11
#   Total train batch size = 16
#     <div>
#
#       <progress value='11' max='11' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [11/11 00:03, Epoch 1/0]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# The `max_length` is `None`. Using the maximum acceptable length according to the current model body: 128.
# Epoch:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# ***** Running evaluation *****
# ***** Running evaluation *****
# #Accuraccy: {'accuracy': 0.6974285714285714}
# Applying column mapping to the training dataset
# Applying column mapping to the evaluation dataset
# #Labels: Counter({0: 13, 1: 11})
# model_head.pkl not found on HuggingFace Hub, initialising classification head with random weights. You should TRAIN this model on a downstream task to use it for predictions and inference.
# Map:   0%|          | 0/24 [00:00<?, ? examples/s]
# ***** Running training *****
#   Num examples = 20
#   Num epochs = 1
#   Total optimization steps = 20
#   Total train batch size = 16
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:06, Epoch 1/0]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# The `max_length` is `None`. Using the maximum acceptable length according to the current model body: 128.
# Epoch:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# ***** Running evaluation *****
# ***** Running evaluation *****
# #Accuraccy: {'accuracy': 0.7392857142857143}
# Applying column mapping to the training dataset
# Applying column mapping to the evaluation dataset
# #Labels: Counter({1: 17, 0: 15})
# model_head.pkl not found on HuggingFace Hub, initialising classification head with random weights. You should TRAIN this model on a downstream task to use it for predictions and inference.
# Map:   0%|          | 0/32 [00:00<?, ? examples/s]
# ***** Running training *****
#   Num examples = 35
#   Num epochs = 1
#   Total optimization steps = 35
#   Total train batch size = 16
#     <div>
#
#       <progress value='35' max='35' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [35/35 00:11, Epoch 1/0]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# The `max_length` is `None`. Using the maximum acceptable length according to the current model body: 128.
# Epoch:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# ***** Running evaluation *****
# ***** Running evaluation *****
# #Accuraccy: {'accuracy': 0.748}
# Applying column mapping to the training dataset
# Applying column mapping to the evaluation dataset
# #Labels: Counter({1: 22, 0: 18})
# model_head.pkl not found on HuggingFace Hub, initialising classification head with random weights. You should TRAIN this model on a downstream task to use it for predictions and inference.
# Map:   0%|          | 0/40 [00:00<?, ? examples/s]
# ***** Running training *****
#   Num examples = 53
#   Num epochs = 1
#   Total optimization steps = 53
#   Total train batch size = 16
#     <div>
#
#       <progress value='53' max='53' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [53/53 00:17, Epoch 1/0]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# The `max_length` is `None`. Using the maximum acceptable length according to the current model body: 128.
# Epoch:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/20 [00:00<?, ?it/s]
# ***** Running evaluation *****
# ***** Running evaluation *****
# #Accuraccy: {'accuracy': 0.7667857142857143}
# Applying column mapping to the training dataset
# Applying column mapping to the evaluation dataset
# #Labels: Counter({1: 25, 0: 23})
# model_head.pkl not found on HuggingFace Hub, initialising classification head with random weights. You should TRAIN this model on a downstream task to use it for predictions and inference.
# Map:   0%|          | 0/48 [00:00<?, ? examples/s]
# ***** Running training *****
#   Num examples = 76
#   Num epochs = 1
#   Total optimization steps = 76
#   Total train batch size = 16
#     <div>
#
#       <progress value='76' max='76' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [76/76 00:25, Epoch 1/0]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# The `max_length` is `None`. Using the maximum acceptable length according to the current model body: 128.
# Epoch:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/24 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/24 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/24 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/24 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/24 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/24 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/24 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/24 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/24 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/24 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/24 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/24 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/24 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/24 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/24 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/24 [00:00<?, ?it/s]
# ***** Running evaluation *****
# ***** Running evaluation *****
# #Accuraccy: {'accuracy': 0.7722142857142857}
