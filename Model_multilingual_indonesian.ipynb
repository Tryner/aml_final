# %%
#Colab

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/MyDrive/aml_final-main/aml_final-main/
#with open("github_token.txt", "r") as f:
#  token = f.read()
#! git clone https://{token}@github.com/Tryner/aml_final.git #clone repo
#%cd aml_final/
#! git pull
! pip install setfit
! pip install -U sentence-transformers
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/aml_final-main/aml_final-main
# Requirement already satisfied: setfit in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: datasets>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from setfit) (2.15.0)
# Requirement already satisfied: sentence-transformers>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from setfit) (2.2.2)
# Requirement already satisfied: evaluate>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from setfit) (0.4.1)
# Requirement already satisfied: huggingface-hub>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from setfit) (0.19.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from setfit) (1.2.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (9.0.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (0.70.15)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (3.9.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (6.0.1)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from evaluate>=0.3.0->setfit) (0.18.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.0->setfit) (3.13.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.0->setfit) (4.5.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (4.35.2)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (0.16.0+cu118)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (1.11.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (0.1.99)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->setfit) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->setfit) (3.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.3.0->setfit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.3.0->setfit) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.3.0->setfit) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.3.0->setfit) (2023.11.17)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.1->setfit) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.1->setfit) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.1->setfit) (0.4.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=2.2.1->setfit) (8.1.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.3.0->setfit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.3.0->setfit) (2023.3.post1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=2.2.1->setfit) (9.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets>=2.3.0->setfit) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (1.3.0)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.35.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.16.0+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.19.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.4.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)

# %%
from collections import Counter

import torch
from data.load_datasets import load_spanish_dataset
from data.load_datasets import load_indonesian_dataset
from datasets import load_dataset, Dataset
from setfit import SetFitModel, Trainer, TrainingArguments
from train.active_learning import ActiveTrainer
from train.active_learning_config import ActiveLearningConfig
from data.dataset_config import DatasetConfig
from sentence_transformers import SentenceTransformer

# %%
dataset = load_indonesian_dataset()
active_learning_config = ActiveLearningConfig()
dataset_config = DatasetConfig()
train_args = TrainingArguments()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
def model_init():
    return SetFitModel.from_pretrained("thenlper/gte-small", use_differentiable_head=True, head_params={"out_features": dataset_config.num_classes}).to(device)
def after_train_callback(trainer: Trainer):
    print("#Accuraccy: " + str(trainer.evaluate()))
def dataset_callback(dataset: Dataset):
    print("#Labels: " + str(Counter(dataset[dataset_config.label_column])))
# Out:
# cpu

# %%
trainer = ActiveTrainer(
    model_init=model_init,
    full_train_dataset=dataset["train"],
    eval_dataset=dataset["validation"],
    train_args=train_args,
    active_learning_config=active_learning_config,
    dataset_config=dataset_config,
    after_train_callback=after_train_callback,
    dataset_callback=dataset_callback,
    )
# Out:
# Casting the dataset:   0%|          | 0/8 [00:00<?, ? examples/s]

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Applying column mapping to the training dataset
# Applying column mapping to the evaluation dataset
# config.json:   0%|          | 0.00/583 [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/68.1k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/583 [00:00<?, ?B/s]
# model.mlmodel:   0%|          | 0.00/122k [00:00<?, ?B/s]
# weight.bin:   0%|          | 0.00/133M [00:00<?, ?B/s]
# (…)on/float32_model.mlpackage/Manifest.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/66.7M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/66.8M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/394 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# model_head.pkl not found on HuggingFace Hub, initialising classification head with random weights. You should TRAIN this model on a downstream task to use it for predictions and inference.
# Map:   0%|          | 0/8 [00:00<?, ? examples/s]
# ***** Running training *****
#   Num examples = 3
#   Num epochs = 1
#   Total optimization steps = 3
#   Total train batch size = 16
#     <div>
#
#       <progress value='3' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3/3 00:09, Epoch 1/0]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# The `max_length` is `None`. Using the maximum acceptable length according to the current model body: 512.
# Epoch:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4 [00:00<?, ?it/s]
# ***** Running evaluation *****
# #Accuraccy: {'accuracy': 0.4646098003629764}
# Total sentences: 1468
# Labeled sentences: 8
# Unlabeled sentences: 1460
# Applying column mapping to the training dataset
# Applying column mapping to the evaluation dataset
# Selected sentences: ['Rasa gelisah, takut, terbebani memang harus di hadapi tiap saat. .gk bisa ngerasa lepas dari beban, sampai nanti, sampai nafas terakhir..Itulah kehidupan :)', 'Semenjak mimpi tidur gue gelisah udah 2 hari ini', 'perasaan gelisah seperti akan kehilangan sesuatu yang sangat berharga.', 'Ketika hati sedang gundah, gelisah dan dipenuhi dengan keputusasaan, ingatlah bahwa hanya kepada Tuhan kita mengadu.', 'Gelisah bgt milih gitar. Yang tau gitar akustik saran ke jog! Mending cort/yamaha? Bajet max 2.5jt', 'baru aja tadi cemas melihat ayen nangis eh liat hospla season 2 tayang 17 juni langsung seneng.. emang aneh aku😌😌', 'kebanyakan orang bakal gelisah atau merasa gak nyaman ketika bab sehari bisa sampe 3x,beda dengan aing merasa gelisah seharian full ga bab kan bgst biasa min 1x max 3x hari ini full aing can modol ieu mamah kumaha ih:(', 'Tidak menyesali ataupun dendam/marah pada hal-hal yang sudah berlalu, dan tidak menaruh rasa cemas yang berlebihan akan masa mendatang, itulah ketenangan sejati"']
# Frasi etichettate:
# 197. Rasa gelisah, takut, terbebani memang harus di hadapi tiap saat. .gk bisa ngerasa lepas dari beban, sampai nanti, sampai nafas terakhir..Itulah kehidupan :) - Etichetta: 0
# 1077. Semenjak mimpi tidur gue gelisah udah 2 hari ini - Etichetta: 0
# 287. perasaan gelisah seperti akan kehilangan sesuatu yang sangat berharga. - Etichetta: 0
# 182. Ketika hati sedang gundah, gelisah dan dipenuhi dengan keputusasaan, ingatlah bahwa hanya kepada Tuhan kita mengadu. - Etichetta: 0
# 696. Gelisah bgt milih gitar. Yang tau gitar akustik saran ke jog! Mending cort/yamaha? Bajet max 2.5jt - Etichetta: 0
# 527. baru aja tadi cemas melihat ayen nangis eh liat hospla season 2 tayang 17 juni langsung seneng.. emang aneh aku😌😌 - Etichetta: 0
# 158. kebanyakan orang bakal gelisah atau merasa gak nyaman ketika bab sehari bisa sampe 3x,beda dengan aing merasa gelisah seharian full ga bab kan bgst biasa min 1x max 3x hari ini full aing can modol ieu mamah kumaha ih:( - Etichetta: 0
# 724. Tidak menyesali ataupun dendam/marah pada hal-hal yang sudah berlalu, dan tidak menaruh rasa cemas yang berlebihan akan masa mendatang, itulah ketenangan sejati" - Etichetta: 0
# #Labels: Counter({0: 12, 1: 4})
# model_head.pkl not found on HuggingFace Hub, initialising classification head with random weights. You should TRAIN this model on a downstream task to use it for predictions and inference.
# Map:   0%|          | 0/16 [00:00<?, ? examples/s]
# ***** Running training *****
#   Num examples = 11
#   Num epochs = 1
#   Total optimization steps = 11
#   Total train batch size = 16
#     <div>
#
#       <progress value='11' max='11' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [11/11 01:18, Epoch 1/0]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# The `max_length` is `None`. Using the maximum acceptable length according to the current model body: 512.
# Epoch:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8 [00:00<?, ?it/s]
# ***** Running evaluation *****
# #Accuraccy: {'accuracy': 0.647912885662432}
# Total sentences: 1468
# Labeled sentences: 16
# Unlabeled sentences: 1452
# Applying column mapping to the training dataset
# Applying column mapping to the evaluation dataset
# Selected sentences: ['kenapa dalam dunia ni aku je nak ikut kepala memasing kenapa aku?', 'Ntah butuh brp tahun terjun sampe bisa ngerasain turun jaga tanpa rasa cemas 😶🥲', 'Dijual : Rasa cemas..Sepertinya sekarang menjadi komoditas yang laku dijual.', 'Slalu dihantui rasa cemas', 'Balik gawe tiba tiba hati deg deg an, perasaan cemas dan gak tau karena apa :(.', 'Cemas aja gatau knp', 'Help! .Akhir-akhir ini tiap ketemu orang banyak yang nggak ku kenal, selalu ngerasa pusing banget, perut tiba-tiba mual, cemas, panik. Cara ngatasinnya gimana sih? Dan itu kenapa sih?', 'Tuhan Masih Menulis CeritaMu.Jadi Tidak Perlu Cemas.Karena CeritaMu Di Tulis Oleh .Penulis Skenario Terbaik :)']
# Frasi etichettate:
# 139. kenapa dalam dunia ni aku je nak ikut kepala memasing kenapa aku? - Etichetta: 0
# 1278. Ntah butuh brp tahun terjun sampe bisa ngerasain turun jaga tanpa rasa cemas 😶🥲 - Etichetta: 1
# 51. Dijual : Rasa cemas..Sepertinya sekarang menjadi komoditas yang laku dijual. - Etichetta: 0
# 540. Slalu dihantui rasa cemas - Etichetta: 1
# 858. Balik gawe tiba tiba hati deg deg an, perasaan cemas dan gak tau karena apa :(. - Etichetta: 1
# 230. Cemas aja gatau knp - Etichetta: 1
# 288. Help! .Akhir-akhir ini tiap ketemu orang banyak yang nggak ku kenal, selalu ngerasa pusing banget, perut tiba-tiba mual, cemas, panik. Cara ngatasinnya gimana sih? Dan itu kenapa sih? - Etichetta: 1
# 817. Tuhan Masih Menulis CeritaMu.Jadi Tidak Perlu Cemas.Karena CeritaMu Di Tulis Oleh .Penulis Skenario Terbaik :) - Etichetta: 0
# #Labels: Counter({0: 15, 1: 9})
# model_head.pkl not found on HuggingFace Hub, initialising classification head with random weights. You should TRAIN this model on a downstream task to use it for predictions and inference.
# Map:   0%|          | 0/24 [00:00<?, ? examples/s]
# ***** Running training *****
#   Num examples = 21
#   Num epochs = 1
#   Total optimization steps = 21
#   Total train batch size = 16
#     <div>
#
#       <progress value='21' max='21' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [21/21 02:34, Epoch 1/0]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# The `max_length` is `None`. Using the maximum acceptable length according to the current model body: 512.
# Epoch:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/12 [00:00<?, ?it/s]
# ***** Running evaluation *****
# #Accuraccy: {'accuracy': 0.6569872958257713}
# Total sentences: 1468
# Labeled sentences: 24
# Unlabeled sentences: 1444
# Applying column mapping to the training dataset
# Applying column mapping to the evaluation dataset
# Selected sentences: ['oke... aku lagi cemas... tiba tiba denger suara bersin.... ini pikiran ku yang lagi cemas atau gimana ini... bersin nya pelan banget lagi... shit.... jangan bikin pikiran ku aneh aneh deh:"))', '[cm] ada yg punya ritual/tips biar bisa konsen dan ga cemas buat ngerjain skripsi?', 'Jgn terlalu cemas kawan,', 'Ngomong jujur pun orang kaya saya dikira bohong. Kikuk dan cemas', 'Badan ngilu, tidur ga nyenyak, pikiran cemas, pertanda apakah itu?', 'Tadi waktu masi dikantor ibu wa di grup keluarga klo ibu tiba2 anosmia dan pulang kerja ibu langsung swab antigen dan hasilnya positif. Besok sekeluarga swab pcr. Mohon doany biar hasil swab pcr sekeluarga negatif. Jujur aku cemas 😭', 'Terlalu cemas.Terlalu khawatir.Terlalu takut', 'udah semingguan rasanya gelisah terus kepala rasanya penuh pengen istirahat pdh tidur terus']
# Frasi etichettate:
# 917. oke... aku lagi cemas... tiba tiba denger suara bersin.... ini pikiran ku yang lagi cemas atau gimana ini... bersin nya pelan banget lagi... shit.... jangan bikin pikiran ku aneh aneh deh:")) - Etichetta: 0
# 759. [cm] ada yg punya ritual/tips biar bisa konsen dan ga cemas buat ngerjain skripsi? - Etichetta: 0
# 242. Jgn terlalu cemas kawan, - Etichetta: 0
# 1092. Ngomong jujur pun orang kaya saya dikira bohong. Kikuk dan cemas - Etichetta: 1
# 981. Badan ngilu, tidur ga nyenyak, pikiran cemas, pertanda apakah itu? - Etichetta: 1
# 992. Tadi waktu masi dikantor ibu wa di grup keluarga klo ibu tiba2 anosmia dan pulang kerja ibu langsung swab antigen dan hasilnya positif. Besok sekeluarga swab pcr. Mohon doany biar hasil swab pcr sekeluarga negatif. Jujur aku cemas 😭 - Etichetta: 0
# 177. Terlalu cemas.Terlalu khawatir.Terlalu takut - Etichetta: 1
# 314. udah semingguan rasanya gelisah terus kepala rasanya penuh pengen istirahat pdh tidur terus - Etichetta: 1
# #Labels: Counter({0: 19, 1: 13})
# model_head.pkl not found on HuggingFace Hub, initialising classification head with random weights. You should TRAIN this model on a downstream task to use it for predictions and inference.
# Map:   0%|          | 0/32 [00:00<?, ? examples/s]
# ***** Running training *****
#   Num examples = 36
#   Num epochs = 1
#   Total optimization steps = 36
#   Total train batch size = 16
#     <div>
#
#       <progress value='36' max='36' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [36/36 04:41, Epoch 1/0]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# The `max_length` is `None`. Using the maximum acceptable length according to the current model body: 512.
# Epoch:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# ***** Running evaluation *****
# #Accuraccy: {'accuracy': 0.6515426497277677}
# Total time taken for training: 1639.1416404247284 seconds
